# %%
import pandas as pd
metadata = pd.read_csv('movie_metadata.csv')
metadata[['movie_title', 'actor_1_name','actor_2_name','actor_3_name','director_name', 'plot_keywords', 'genres']].head(5)
# Out:
#                                          movie_title     actor_1_name  \
# 0                                            Avatar       CCH Pounder
# 1          Pirates of the Caribbean: At World's End       Johnny Depp
# 2                                           Spectre   Christoph Waltz
# 3                             The Dark Knight Rises         Tom Hardy
# 4  Star Wars: Episode VII - The Force Awakens    ...      Doug Walker
#
#        actor_2_name          actor_3_name      director_name  \
# 0  Joel David Moore             Wes Studi      James Cameron
# 1     Orlando Bloom        Jack Davenport     Gore Verbinski
# 2      Rory Kinnear      Stephanie Sigman         Sam Mendes
# 3    Christian Bale  Joseph Gordon-Levitt  Christopher Nolan
# 4        Rob Walker                   NaN        Doug Walker
#
#                                        plot_keywords  \
# 0             avatar|future|marine|native|paraplegic
# 1  goddess|marriage ceremony|marriage proposal|pi...
# 2                bomb|espionage|sequel|spy|terrorist
# 3  deception|imprisonment|lawlessness|police offi...
# 4                                                NaN
#
#                             genres
# 0  Action|Adventure|Fantasy|Sci-Fi
# 1         Action|Adventure|Fantasy
# 2        Action|Adventure|Thriller
# 3                  Action|Thriller
# 4                      Documentary

# %% [markdown]
# #### Filtering Data

# %%
#Combine actors in a cast
metadata['cast'] = metadata['actor_1_name'].str.cat(metadata[['actor_2_name', 'actor_3_name']], sep='|', na_rep='')
metadata[['movie_title', 'cast','director_name', 'plot_keywords', 'genres']].head(5)
# Out:
#                                          movie_title  \
# 0                                            Avatar
# 1          Pirates of the Caribbean: At World's End
# 2                                           Spectre
# 3                             The Dark Knight Rises
# 4  Star Wars: Episode VII - The Force Awakens    ...
#
#                                             cast      director_name  \
# 0         CCH Pounder|Joel David Moore|Wes Studi      James Cameron
# 1       Johnny Depp|Orlando Bloom|Jack Davenport     Gore Verbinski
# 2  Christoph Waltz|Rory Kinnear|Stephanie Sigman         Sam Mendes
# 3  Tom Hardy|Christian Bale|Joseph Gordon-Levitt  Christopher Nolan
# 4                        Doug Walker|Rob Walker|        Doug Walker
#
#                                        plot_keywords  \
# 0             avatar|future|marine|native|paraplegic
# 1  goddess|marriage ceremony|marriage proposal|pi...
# 2                bomb|espionage|sequel|spy|terrorist
# 3  deception|imprisonment|lawlessness|police offi...
# 4                                                NaN
#
#                             genres
# 0  Action|Adventure|Fantasy|Sci-Fi
# 1         Action|Adventure|Fantasy
# 2        Action|Adventure|Thriller
# 3                  Action|Thriller
# 4                      Documentary

# %%
#Converting many values in a list
def converToList(feature):
    values = []
    for ind in metadata.index:
        current_list = str(metadata[feature][ind]).split('|')
        normalized_list = [x for x in current_list if pd.isnull(x) == False and x != '']
        values.append(normalized_list)
    return values

# %%
features = ['cast', 'plot_keywords', 'genres']
for feature in features:
    metadata[feature] = converToList(feature)

# %%
metadata[['movie_title', 'cast','director_name', 'plot_keywords', 'genres']].head(5)
# Out:
#                                          movie_title  \
# 0                                            Avatar
# 1          Pirates of the Caribbean: At World's End
# 2                                           Spectre
# 3                             The Dark Knight Rises
# 4  Star Wars: Episode VII - The Force Awakens    ...
#
#                                                 cast      director_name  \
# 0         [CCH Pounder, Joel David Moore, Wes Studi]      James Cameron
# 1       [Johnny Depp, Orlando Bloom, Jack Davenport]     Gore Verbinski
# 2  [Christoph Waltz, Rory Kinnear, Stephanie Sigman]         Sam Mendes
# 3  [Tom Hardy, Christian Bale, Joseph Gordon-Levitt]  Christopher Nolan
# 4                          [Doug Walker, Rob Walker]        Doug Walker
#
#                                        plot_keywords  \
# 0       [avatar, future, marine, native, paraplegic]
# 1  [goddess, marriage ceremony, marriage proposal...
# 2          [bomb, espionage, sequel, spy, terrorist]
# 3  [deception, imprisonment, lawlessness, police ...
# 4                                              [nan]
#
#                                  genres
# 0  [Action, Adventure, Fantasy, Sci-Fi]
# 1          [Action, Adventure, Fantasy]
# 2         [Action, Adventure, Thriller]
# 3                    [Action, Thriller]
# 4                         [Documentary]

# %% [markdown]
# #### Cleaning Data

# %%
# Function to convert all strings to lower case and strip names of spaces
def clean_data(x):
    if isinstance(x, list):
        return [str.lower(i.replace(" ", "")) for i in x]
    else:
        #Check if director exists. If not, return empty string
        if isinstance(x, str):
            return str.lower(x.replace(" ", ""))
        else:
            return ''

# %%
features = ['cast', 'plot_keywords', 'director_name', 'genres']

for feature in features:
    metadata[feature] = metadata[feature].apply(clean_data)

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)
metadata[['movie_title', 'cast','director_name', 'plot_keywords', 'genres']].head(50)
# Out:
#                                           movie_title  \
# 0                                             Avatar
# 1           Pirates of the Caribbean: At World's End
# 2                                            Spectre
# 3                              The Dark Knight Rises
# 4   Star Wars: Episode VII - The Force Awakens    ...
# 5                                        John Carter
# 6                                       Spider-Man 3
# 7                                            Tangled
# 8                            Avengers: Age of Ultron
# 9             Harry Potter and the Half-Blood Prince
# 10                Batman v Superman: Dawn of Justice
# 11                                  Superman Returns
# 12                                 Quantum of Solace
# 13        Pirates of the Caribbean: Dead Man's Chest
# 14                                   The Lone Ranger
# 15                                      Man of Steel
# 16          The Chronicles of Narnia: Prince Caspian
# 17                                      The Avengers
# 18       Pirates of the Caribbean: On Stranger Tides
# 19                                    Men in Black 3
# 20         The Hobbit: The Battle of the Five Armies
# 21                            The Amazing Spider-Man
# 22                                        Robin Hood
# 23               The Hobbit: The Desolation of Smaug
# 24                                The Golden Compass
# 25                                         King Kong
# 26                                           Titanic
# 27                        Captain America: Civil War
# 28                                        Battleship
# 29                                    Jurassic World
# 30                                           Skyfall
# 31                                      Spider-Man 2
# 32                                        Iron Man 3
# 33                               Alice in Wonderland
# 34                             X-Men: The Last Stand
# 35                               Monsters University
# 36               Transformers: Revenge of the Fallen
# 37                   Transformers: Age of Extinction
# 38                         Oz the Great and Powerful
# 39                          The Amazing Spider-Man 2
# 40                                      TRON: Legacy
# 41                                            Cars 2
# 42                                     Green Lantern
# 43                                       Toy Story 3
# 44                              Terminator Salvation
# 45                                         Furious 7
# 46                                       World War Z
# 47                        X-Men: Days of Future Past
# 48                           Star Trek Into Darkness
# 49                             Jack the Giant Slayer
#
#                                                  cast     director_name  \
# 0              [cchpounder, joeldavidmoore, wesstudi]      jamescameron
# 1           [johnnydepp, orlandobloom, jackdavenport]     goreverbinski
# 2      [christophwaltz, rorykinnear, stephaniesigman]         sammendes
# 3      [tomhardy, christianbale, josephgordon-levitt]  christophernolan
# 4                             [dougwalker, robwalker]        dougwalker
# 5          [darylsabara, samanthamorton, pollywalker]     andrewstanton
# 6            [j.k.simmons, jamesfranco, kirstendunst]          samraimi
# 7              [bradgarrett, donnamurphy, m.c.gainey]       nathangreno
# 8   [chrishemsworth, robertdowneyjr., scarlettjoha...        josswhedon
# 9         [alanrickman, danielradcliffe, rupertgrint]        davidyates
# 10           [henrycavill, laurencohan, aland.purwin]        zacksnyder
# 11         [kevinspacey, marlonbrando, franklangella]       bryansinger
# 12   [giancarlogiannini, mathieuamalric, rorykinnear]       marcforster
# 13          [johnnydepp, orlandobloom, jackdavenport]     goreverbinski
# 14             [johnnydepp, ruthwilson, tomwilkinson]     goreverbinski
# 15      [henrycavill, christophermeloni, harrylennix]        zacksnyder
# 16  [peterdinklage, pierfrancescofavino, damiánalc...     andrewadamson
# 17  [chrishemsworth, robertdowneyjr., scarlettjoha...        josswhedon
# 18            [johnnydepp, samclaflin, stephengraham]       robmarshall
# 19   [willsmith, michaelstuhlbarg, nicolescherzinger]   barrysonnenfeld
# 20             [aidanturner, adambrown, jamesnesbitt]      peterjackson
# 21            [emmastone, andrewgarfield, chriszylka]          marcwebb
# 22               [markaddy, williamhurt, scottgrimes]       ridleyscott
# 23             [aidanturner, adambrown, jamesnesbitt]      peterjackson
# 24     [christopherlee, evagreen, kristinscottthomas]        chrisweitz
# 25         [naomiwatts, thomaskretschmann, evanparke]      peterjackson
# 26      [leonardodicaprio, katewinslet, gloriastuart]      jamescameron
# 27   [robertdowneyjr., scarlettjohansson, chrisevans]      anthonyrusso
# 28    [liamneeson, alexanderskarsgård, tadanobuasano]         peterberg
# 29             [brycedallashoward, judygreer, omarsy]    colintrevorrow
# 30          [albertfinney, helenmccrory, rorykinnear]         sammendes
# 31           [j.k.simmons, jamesfranco, kirstendunst]          samraimi
# 32          [robertdowneyjr., jonfavreau, doncheadle]        shaneblack
# 33            [johnnydepp, alanrickman, annehathaway]         timburton
# 34        [hughjackman, kelseygrammer, danielcudmore]       brettratner
# 35             [stevebuscemi, tylerlabine, seanhayes]        danscanlon
# 36        [glennmorshower, kevindunn, ramonrodriguez]        michaelbay
# 37           [bingbingli, sophiamyles, kelseygrammer]        michaelbay
# 38                [timholmes, milakunis, jamesfranco]          samraimi
# 39             [emmastone, andrewgarfield, b.j.novak]          marcwebb
# 40             [jeffbridges, oliviawilde, jamesfrain]    josephkosinski
# 41      [joemantegna, thomaskretschmann, eddieizzard]      johnlasseter
# 42      [ryanreynolds, temueramorrison, taikawaititi]    martincampbell
# 43           [tomhanks, johnratzenberger, donrickles]        leeunkrich
# 44         [christianbale, brycedallashoward, common]               mcg
# 45              [jasonstatham, paulwalker, vindiesel]          jameswan
# 46             [petercapaldi, bradpitt, mireilleenos]       marcforster
# 47     [jenniferlawrence, peterdinklage, hughjackman]       bryansinger
# 48  [benedictcumberbatch, brucegreenwood, noelclarke]        j.j.abrams
# 49             [eddiemarsan, ewenbremner, ralphbrown]       bryansinger
#
#                                         plot_keywords  \
# 0        [avatar, future, marine, native, paraplegic]
# 1   [goddess, marriageceremony, marriageproposal, ...
# 2           [bomb, espionage, sequel, spy, terrorist]
# 3   [deception, imprisonment, lawlessness, policeo...
# 4                                               [nan]
# 5   [alien, americancivilwar, malenipple, mars, pr...
# 6      [sandman, spiderman, symbiote, venom, villain]
# 7   [17thcentury, basedonfairytale, disney, flower...
# 8   [artificialintelligence, basedoncomicbook, cap...
# 9              [blood, book, love, potion, professor]
# 10  [basedoncomicbook, batman, sequeltoareboot, su...
# 11  [crystal, epic, lexluthor, loislane, returntoe...
# 12  [actionhero, attemptedrape, bondgirl, official...
# 13  [boxofficehit, giantsquid, heart, liar'sdice, ...
# 14         [horse, outlaw, texas, texasranger, train]
# 15  [basedoncomicbook, britishactorplayingamerican...
# 16  [brotherbrotherrelationship, brothersisterrela...
# 17  [alieninvasion, assassin, battle, ironman, sol...
# 18    [blackbeard, captain, pirate, revenge, soldier]
# 19  [alien, criminal, m.i.b., maximumsecuritypriso...
# 20              [army, elf, hobbit, middleearth, orc]
# 21     [lizard, outcast, spider, spiderman, teenager]
# 22  [1190s, archer, england, kingofengland, robinh...
# 23  [dwarf, elf, laketown, mountain, swordandsorcery]
# 24              [children, epic, friend, girl, quest]
# 25  [animalnameintitle, apeabductsawoman, gorilla,...
# 26                 [artist, love, ship, titanic, wet]
# 27  [basedoncomicbook, knife, marvelcinematicunive...
# 28   [boxofficeflop, hawaii, naval, oahuhawaii, ship]
# 29  [dinosaur, disasterfilm, experimentgonewrong, ...
# 30  [brawl, childhoodhome, computercracker, intell...
# 31  [death, doctor, scientist, supervillain, tenta...
# 32  [armor, explosion, humanbomb, missileattack, t...
# 33  [aliceinwonderland, mistakingrealityfordream, ...
# 34  [battle, mutant, outrage, walkingthroughawall,...
# 35  [cheating, fraternity, monster, singinginacar,...
# 36        [autobot, decepticon, machine, sun, symbol]
# 37  [blockbuster, bumblebeethecharacter, semitruck...
# 38               [circus, magic, magician, oz, witch]
# 39  [costumedhero, deathofgirlfriend, maskedvigila...
# 40   [arcade, bridge, disappearance, escape, warrior]
# 41  [bestfriend, carrace, conspiracy, gadgetcar, spy]
# 42        [autopsy, lantern, planet, ring, testpilot]
# 43         [college, daycare, escape, teddybear, toy]
# 44        [deathrow, future, machine, rescue, skynet]
# 45  [carfallingoffacliff, hospital, revenge, stard...
# 46      [chaos, disease, infection, pandemic, zombie]
# 47  [dystopia, superstrength, supernaturalpower, t...
# 48        [admiral, captain, manhunt, mission, space]
# 49    [bean, giant, king, noopeningcredits, princess]
#
#                                                genres
# 0                [action, adventure, fantasy, sci-fi]
# 1                        [action, adventure, fantasy]
# 2                       [action, adventure, thriller]
# 3                                  [action, thriller]
# 4                                       [documentary]
# 5                         [action, adventure, sci-fi]
# 6                        [action, adventure, romance]
# 7   [adventure, animation, comedy, family, fantasy...
# 8                         [action, adventure, sci-fi]
# 9               [adventure, family, fantasy, mystery]
# 10                        [action, adventure, sci-fi]
# 11                        [action, adventure, sci-fi]
# 12                                [action, adventure]
# 13                       [action, adventure, fantasy]
# 14                       [action, adventure, western]
# 15               [action, adventure, fantasy, sci-fi]
# 16               [action, adventure, family, fantasy]
# 17                        [action, adventure, sci-fi]
# 18                       [action, adventure, fantasy]
# 19  [action, adventure, comedy, family, fantasy, s...
# 20                               [adventure, fantasy]
# 21                       [action, adventure, fantasy]
# 22                [action, adventure, drama, history]
# 23                               [adventure, fantasy]
# 24                       [adventure, family, fantasy]
# 25                [action, adventure, drama, romance]
# 26                                   [drama, romance]
# 27                        [action, adventure, sci-fi]
# 28              [action, adventure, sci-fi, thriller]
# 29              [action, adventure, sci-fi, thriller]
# 30                      [action, adventure, thriller]
# 31              [action, adventure, fantasy, romance]
# 32                        [action, adventure, sci-fi]
# 33                       [adventure, family, fantasy]
# 34     [action, adventure, fantasy, sci-fi, thriller]
# 35    [adventure, animation, comedy, family, fantasy]
# 36                        [action, adventure, sci-fi]
# 37                        [action, adventure, sci-fi]
# 38                       [adventure, family, fantasy]
# 39               [action, adventure, fantasy, sci-fi]
# 40                        [action, adventure, sci-fi]
# 41      [adventure, animation, comedy, family, sport]
# 42                        [action, adventure, sci-fi]
# 43    [adventure, animation, comedy, family, fantasy]
# 44                        [action, adventure, sci-fi]
# 45                          [action, crime, thriller]
# 46      [action, adventure, horror, sci-fi, thriller]
# 47     [action, adventure, fantasy, sci-fi, thriller]
# 48                        [action, adventure, sci-fi]
# 49                               [adventure, fantasy]

# %% [markdown]
# #### Creating Soup Field

# %%
def create_soup(x):
    return ' '.join(x['plot_keywords']) + ' ' + ' '.join(x['cast']) + ' ' + x['director_name']
    #return ' '.join(x['plot_keywords']) + ' ' + ' '.join(x['cast']) + ' ' + x['director_name'] + ' ' + ' '.join(x['genres'])

# %%
# Create a new soup feature, falta eliminar el nan del registro 4
metadata['soup'] = metadata.apply(create_soup, axis=1)
metadata[['movie_title','soup']].head(50)
# Out:
#                                           movie_title  \
# 0                                             Avatar
# 1           Pirates of the Caribbean: At World's End
# 2                                            Spectre
# 3                              The Dark Knight Rises
# 4   Star Wars: Episode VII - The Force Awakens    ...
# 5                                        John Carter
# 6                                       Spider-Man 3
# 7                                            Tangled
# 8                            Avengers: Age of Ultron
# 9             Harry Potter and the Half-Blood Prince
# 10                Batman v Superman: Dawn of Justice
# 11                                  Superman Returns
# 12                                 Quantum of Solace
# 13        Pirates of the Caribbean: Dead Man's Chest
# 14                                   The Lone Ranger
# 15                                      Man of Steel
# 16          The Chronicles of Narnia: Prince Caspian
# 17                                      The Avengers
# 18       Pirates of the Caribbean: On Stranger Tides
# 19                                    Men in Black 3
# 20         The Hobbit: The Battle of the Five Armies
# 21                            The Amazing Spider-Man
# 22                                        Robin Hood
# 23               The Hobbit: The Desolation of Smaug
# 24                                The Golden Compass
# 25                                         King Kong
# 26                                           Titanic
# 27                        Captain America: Civil War
# 28                                        Battleship
# 29                                    Jurassic World
# 30                                           Skyfall
# 31                                      Spider-Man 2
# 32                                        Iron Man 3
# 33                               Alice in Wonderland
# 34                             X-Men: The Last Stand
# 35                               Monsters University
# 36               Transformers: Revenge of the Fallen
# 37                   Transformers: Age of Extinction
# 38                         Oz the Great and Powerful
# 39                          The Amazing Spider-Man 2
# 40                                      TRON: Legacy
# 41                                            Cars 2
# 42                                     Green Lantern
# 43                                       Toy Story 3
# 44                              Terminator Salvation
# 45                                         Furious 7
# 46                                       World War Z
# 47                        X-Men: Days of Future Past
# 48                           Star Trek Into Darkness
# 49                             Jack the Giant Slayer
#
#                                                  soup
# 0   avatar future marine native paraplegic cchpoun...
# 1   goddess marriageceremony marriageproposal pira...
# 2   bomb espionage sequel spy terrorist christophw...
# 3   deception imprisonment lawlessness policeoffic...
# 4                 nan dougwalker robwalker dougwalker
# 5   alien americancivilwar malenipple mars princes...
# 6   sandman spiderman symbiote venom villain j.k.s...
# 7   17thcentury basedonfairytale disney flower tow...
# 8   artificialintelligence basedoncomicbook captai...
# 9   blood book love potion professor alanrickman d...
# 10  basedoncomicbook batman sequeltoareboot superh...
# 11  crystal epic lexluthor loislane returntoearth ...
# 12  actionhero attemptedrape bondgirl officialjame...
# 13  boxofficehit giantsquid heart liar'sdice monst...
# 14  horse outlaw texas texasranger train johnnydep...
# 15  basedoncomicbook britishactorplayingamericanch...
# 16  brotherbrotherrelationship brothersisterrelati...
# 17  alieninvasion assassin battle ironman soldier ...
# 18  blackbeard captain pirate revenge soldier john...
# 19  alien criminal m.i.b. maximumsecurityprison pr...
# 20  army elf hobbit middleearth orc aidanturner ad...
# 21  lizard outcast spider spiderman teenager emmas...
# 22  1190s archer england kingofengland robinhood m...
# 23  dwarf elf laketown mountain swordandsorcery ai...
# 24  children epic friend girl quest christopherlee...
# 25  animalnameintitle apeabductsawoman gorilla isl...
# 26  artist love ship titanic wet leonardodicaprio ...
# 27  basedoncomicbook knife marvelcinematicuniverse...
# 28  boxofficeflop hawaii naval oahuhawaii ship lia...
# 29  dinosaur disasterfilm experimentgonewrong jura...
# 30  brawl childhoodhome computercracker intelligen...
# 31  death doctor scientist supervillain tentacle j...
# 32  armor explosion humanbomb missileattack terror...
# 33  aliceinwonderland mistakingrealityfordream que...
# 34  battle mutant outrage walkingthroughawall xmen...
# 35  cheating fraternity monster singinginacar univ...
# 36  autobot decepticon machine sun symbol glennmor...
# 37  blockbuster bumblebeethecharacter semitruckand...
# 38  circus magic magician oz witch timholmes milak...
# 39  costumedhero deathofgirlfriend maskedvigilante...
# 40  arcade bridge disappearance escape warrior jef...
# 41  bestfriend carrace conspiracy gadgetcar spy jo...
# 42  autopsy lantern planet ring testpilot ryanreyn...
# 43  college daycare escape teddybear toy tomhanks ...
# 44  deathrow future machine rescue skynet christia...
# 45  carfallingoffacliff hospital revenge stardiedb...
# 46  chaos disease infection pandemic zombie peterc...
# 47  dystopia superstrength supernaturalpower timep...
# 48  admiral captain manhunt mission space benedict...
# 49  bean giant king noopeningcredits princess eddi...

# %%
# Entry movie
print(metadata[['soup']].head(5)['soup'][0])
# Out:
# avatar future marine native paraplegic cchpounder joeldavidmoore wesstudi jamescameron

# %%
# Aplying trim to the titles
df_obj = metadata.select_dtypes(['object'])
metadata[df_obj.columns] = df_obj.apply(lambda x: x.str.strip())

# %%
metadata = metadata.reset_index()
indices = pd.Series(metadata.index, index=metadata['movie_title'])

# %% [markdown]
# #### Recomendation Algorithm

# %% [markdown]
# ###### Training Algorithm

# %%
m1 = indices['The Amazing Spider-Man']
m2 = indices['Avengers: Age of Ultron']
m3 = indices['Captain America: Civil War']
m4 = indices['Iron Man 3']

m5 = indices['Toy Story 3']
m6 = indices['Cars 2']


val1 = metadata.iloc[m1]['soup']
val2 = metadata.iloc[m2]['soup']
val3 = metadata.iloc[m3]['soup']
val4 = metadata.iloc[m4]['soup']

val5 = metadata.iloc[m5]['soup']
val6 = metadata.iloc[m6]['soup']

# %%
like = [val1, val2, val3, val4]
unlike = [val5, val6]

# %% [markdown]
# ###### Probabilidad de Like y Unlike

# %%
# Probabilities
total_sentences = len(like) + len(unlike)

p_like = len(like)/total_sentences;
p_unlike = len(unlike)/total_sentences;

# %% [markdown]
# ###### Probabilidad de cada palabra en cada clasificación

# %%
# Frecuencias (Bag of words)
def create_table_freq(corpus):
    freq = {}
    for sent in corpus:
        tokens = sent.split(' ')
        for token in tokens:
            if token not in freq.keys():
                freq[token] = 1
            else:
                freq[token] += 1
    return freq

# %%
freq_like = create_table_freq(like)
freq_unlike = create_table_freq(unlike)

print(freq_like)
print(freq_unlike)
# Out:
# {'lizard': 1, 'outcast': 1, 'spider': 1, 'spiderman': 1, 'teenager': 1, 'emmastone': 1, 'andrewgarfield': 1, 'chriszylka': 1, 'marcwebb': 1, 'artificialintelligence': 1, 'basedoncomicbook': 2, 'captainamerica': 1, 'marvelcinematicuniverse': 2, 'superhero': 2, 'chrishemsworth': 1, 'robertdowneyjr.': 3, 'scarlettjohansson': 2, 'josswhedon': 1, 'knife': 1, 'returningcharacterkilledoff': 1, 'chrisevans': 1, 'anthonyrusso': 1, 'armor': 1, 'explosion': 1, 'humanbomb': 1, 'missileattack': 1, 'terrorist': 1, 'jonfavreau': 1, 'doncheadle': 1, 'shaneblack': 1}
# {'college': 1, 'daycare': 1, 'escape': 1, 'teddybear': 1, 'toy': 1, 'tomhanks': 1, 'johnratzenberger': 1, 'donrickles': 1, 'leeunkrich': 1, 'bestfriend': 1, 'carrace': 1, 'conspiracy': 1, 'gadgetcar': 1, 'spy': 1, 'joemantegna': 1, 'thomaskretschmann': 1, 'eddieizzard': 1, 'johnlasseter': 1}

# %%
# Obteniendo probabilidades de cada palabra
def count_words(corpus):
    freq = 0
    for sent in corpus:
        freq += len(sent.split(' '))
    return freq

# %%
total_like = count_words(like)
total_unlike = count_words(unlike)

print(f'like: {total_like}\nunlike: {total_unlike}')
# Out:
# like: 36
# unlike: 18

# %%
# Transform to Cpt's
def create_cpt(freq, total):
    cpt_eqv = {}
    for k,v in freq.items():
        probability = v/total
        cpt_eqv[k] = probability
    return cpt_eqv

# %%
cpt_like = create_cpt(freq_like, total_like)
cpt_unlike = create_cpt(freq_unlike, total_unlike)
print(cpt_like)
print(cpt_unlike)
# Out:
# {'lizard': 0.027777777777777776, 'outcast': 0.027777777777777776, 'spider': 0.027777777777777776, 'spiderman': 0.027777777777777776, 'teenager': 0.027777777777777776, 'emmastone': 0.027777777777777776, 'andrewgarfield': 0.027777777777777776, 'chriszylka': 0.027777777777777776, 'marcwebb': 0.027777777777777776, 'artificialintelligence': 0.027777777777777776, 'basedoncomicbook': 0.05555555555555555, 'captainamerica': 0.027777777777777776, 'marvelcinematicuniverse': 0.05555555555555555, 'superhero': 0.05555555555555555, 'chrishemsworth': 0.027777777777777776, 'robertdowneyjr.': 0.08333333333333333, 'scarlettjohansson': 0.05555555555555555, 'josswhedon': 0.027777777777777776, 'knife': 0.027777777777777776, 'returningcharacterkilledoff': 0.027777777777777776, 'chrisevans': 0.027777777777777776, 'anthonyrusso': 0.027777777777777776, 'armor': 0.027777777777777776, 'explosion': 0.027777777777777776, 'humanbomb': 0.027777777777777776, 'missileattack': 0.027777777777777776, 'terrorist': 0.027777777777777776, 'jonfavreau': 0.027777777777777776, 'doncheadle': 0.027777777777777776, 'shaneblack': 0.027777777777777776}
# {'college': 0.05555555555555555, 'daycare': 0.05555555555555555, 'escape': 0.05555555555555555, 'teddybear': 0.05555555555555555, 'toy': 0.05555555555555555, 'tomhanks': 0.05555555555555555, 'johnratzenberger': 0.05555555555555555, 'donrickles': 0.05555555555555555, 'leeunkrich': 0.05555555555555555, 'bestfriend': 0.05555555555555555, 'carrace': 0.05555555555555555, 'conspiracy': 0.05555555555555555, 'gadgetcar': 0.05555555555555555, 'spy': 0.05555555555555555, 'joemantegna': 0.05555555555555555, 'thomaskretschmann': 0.05555555555555555, 'eddieizzard': 0.05555555555555555, 'johnlasseter': 0.05555555555555555}

# %% [markdown]
# ###### Recomendation

# %%
def calcLike(texto, alpha):
    p_cadena_like = 1
    p_cadena_unlike = 1
    oracion = texto.split(' ')
    for i in range(len(oracion)):
        if oracion[i] not in cpt_like:
            laplace1 = alpha / ((total_like+total_unlike)+(2*alpha))
            p_cadena_like *=  laplace1
        else:
            p_cadena_like *=  cpt_like[oracion[i]]
        if oracion[i] not in cpt_unlike:
            laplace2 = alpha / ((total_like+total_unlike)+(2*alpha))
            p_cadena_unlike *=  laplace2
        else:
            p_cadena_unlike *=  cpt_unlike[oracion[i]]
    p_final = (p_cadena_like * p_like) / ((p_cadena_like * p_like) + (p_cadena_unlike * p_unlike))
    return p_final

# %%
#Prueba de uno por uno
test = indices['X-Men: Apocalypse']
test_val = metadata.iloc[test]['soup']
#test_val
calcLike(test_val, 1)
# Out:
# 0.8615384615384615
